# %%
import sqlalchemy
import pandas as pd
from datetime import datetime

# %%
from scraper import Scraper
base_url = 'https://www.homedepot.com/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/N-5yc1vZcjnu?NCNI-5&searchRedirect=ceiling%20fan%20with%20lights&semanticToken=k27r10r00f22000000000e_202407051741572580635995840_us-central1-bz9l%20k27r10r00f22000000000e%20%3E%20st%3A%7Bceiling%20fan%20with%20lights%7D%3Ast%20ml%3A%7B24%7D%3Aml%20nr%3A%7Bceiling%20fan%20with%20lights%7D%3Anr%20nf%3A%7Bn%2Fa%7D%3Anf%20qu%3A%7Bceiling%20fan%20with%20lights%7D%3Aqu%20ie%3A%7B0%7D%3Aie%20qr%3A%7Bceiling%20fan%20with%20lights%7D%3Aqr'
scraper = Scraper(base_url)
scraper.scrape(start_page=1, end_page=5)
df = scraper.to_dataframe()

# %%
df = df.reset_index()

# %%
df['date'] = datetime.today().date()
df
# Out:
#      Number      Label        Brand  \
# 0         1  Top Rated         None
# 1         2  Exclusive         None
# 2         3  Top Rated  Hampton Bay
# 3         4  Sponsored  Bella Depot
# 4         5  Exclusive       Hunter
# ..      ...        ...          ...
# 278     279  Exclusive  Hampton Bay
# 279     280       None       TOZING
# 280     281       None       Hunter
# 281     282  Sponsored      Sofucor
# 282     283  Sponsored       TOZING
#
#                                                  Title    price Review_Number  \
# 0    Hugger 52 in. LED Indoor Black Ceiling Fan wit...   $49.98         10337
# 1    Bellina 42 in. Oil-Rubbed Bronze Ceiling Fan w...   $59.97           567
# 2    Mena 54 in. White Color Changing Integrated LE...  $159.00           611
# 3    18 in. Smart Indoor Black Metal Standard Ceili...  $126.00          None
# 4    Oakhurst 52 in. LED Indoor Low Profile Brushed...  $114.00          2512
# ..                                                 ...      ...           ...
# 278  Stoneridge 52 in. LED Indoor/Outdoor Bronze Hu...   $87.20          None
# 279  19.6 in. Indoor Bronze Low Profile Fabric Farm...  $132.00            38
# 280  Builder Plus 52 in. Indoor 3-Light Brushed Nic...  $149.99           228
# 281  52 in. Indoor/Outdoor 5 Blades Black Downrod C...  $186.23            12
# 282  19.6 in. LED Modern Indoor Black Enclosed Low ...   $99.00             4
#
#                                                   href        date
# 0    https://www.homedepot.com/p/Hugger-52-in-LED-I...  2024-07-10
# 1    https://www.homedepot.com/p/Bellina-42-in-Oil-...  2024-07-10
# 2    https://www.homedepot.com/p/Hampton-Bay-Mena-5...  2024-07-10
# 3    https://www.homedepot.com/p/Bella-Depot-18-in-...  2024-07-10
# 4    https://www.homedepot.com/p/Hunter-Oakhurst-52...  2024-07-10
# ..                                                 ...         ...
# 278  https://www.homedepot.com/p/Hampton-Bay-Stoner...  2024-07-10
# 279  https://www.homedepot.com/p/TOZING-19-6-in-Ind...  2024-07-10
# 280  https://www.homedepot.com/p/Hunter-Builder-Plu...  2024-07-10
# 281  https://www.homedepot.com/p/Sofucor-52-in-Indo...  2024-07-10
# 282  https://www.homedepot.com/p/TOZING-19-6-in-LED...  2024-07-10
#
# [283 rows x 8 columns]

# %%
# Connect to the database
conn = sqlalchemy.create_engine(
'mysql+mysqlconnector://root:0803@localhost:3306/hd_products')

# %%
df.to_sql(name='products', con=conn, if_exists='replace', index=False)
# Out:
# 104
