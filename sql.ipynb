# %%
import sqlalchemy
import pandas as pd
from datetime import datetime

# %%
from scraper import Scraper
base_url = 'https://www.homedepot.com/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/N-5yc1vZcjnu?NCNI-5&searchRedirect=ceiling%20fan%20with%20lights&semanticToken=k27r10r00f22000000000e_202407051741572580635995840_us-central1-bz9l%20k27r10r00f22000000000e%20%3E%20st%3A%7Bceiling%20fan%20with%20lights%7D%3Ast%20ml%3A%7B24%7D%3Aml%20nr%3A%7Bceiling%20fan%20with%20lights%7D%3Anr%20nf%3A%7Bn%2Fa%7D%3Anf%20qu%3A%7Bceiling%20fan%20with%20lights%7D%3Aqu%20ie%3A%7B0%7D%3Aie%20qr%3A%7Bceiling%20fan%20with%20lights%7D%3Aqr'
scraper = Scraper(base_url)
scraper.scrape(start_page=1, end_page=5)
df = scraper.to_dataframe()

# %%
df = df.reset_index()

# %%
df['date'] = datetime.today().date()
df
# Out:
#      Number      Label          Brand  \
# 0         1  Top Rated           None
# 1         2  Exclusive           None
# 2         6       None  Bell + Howell
# 3         7       None           None
# 4        11       None           None
# ..      ...        ...            ...
# 100     246       None     IHOMEadore
# 101     247       None         Hunter
# 102     248       None           None
# 103     249       None          CARRO
# 104     250       None          CARRO
#
#                                                  Title    price Review_Number  \
# 0    Hugger 52 in. LED Indoor Black Ceiling Fan wit...   $49.98         10337
# 1    Bellina 42 in. Oil-Rubbed Bronze Ceiling Fan w...   $59.97           567
# 2    15.7 in. Indoor White Ceiling Fan with Remote,...   $49.97           483
# 3    Littleton 42 in. LED Indoor White Ceiling Fan ...   $44.97          2025
# 4    Clarkston II 44 in. LED Indoor White Ceiling F...   $76.97          2645
# ..                                                 ...      ...           ...
# 100  52 in. LED Indoor Natural Brass Ceiling Fan wi...  $229.32             4
# 101  Avenue 52 in. Indoor Noble Bronze Ceiling Fan ...  $149.00            23
# 102  32 in. LED Indoor White Small Ceiling Fan with...   $89.69             2
# 103  Voyager 52 in. Dimmable LED Indoor/Outdoor Bla...  $189.00            29
# 104  Wilkes 52 in. Dimmable LED Indoor/Outdoor Whit...  $179.00             6
#
#                                                   href        date
# 0    https://www.homedepot.com/p/Hugger-52-in-LED-I...  2024-07-09
# 1    https://www.homedepot.com/p/Bellina-42-in-Oil-...  2024-07-09
# 2    https://www.homedepot.com/p/Bell-Howell-15-7-i...  2024-07-09
# 3    https://www.homedepot.com/p/Littleton-42-in-LE...  2024-07-09
# 4    https://www.homedepot.com/p/Clarkston-II-44-in...  2024-07-09
# ..                                                 ...         ...
# 100  https://www.homedepot.com/p/IHOMEadore-52-in-L...  2024-07-09
# 101  https://www.homedepot.com/p/Hunter-Avenue-52-i...  2024-07-09
# 102  https://www.homedepot.com/p/32-in-LED-Indoor-W...  2024-07-09
# 103  https://www.homedepot.com/p/CARRO-Voyager-52-i...  2024-07-09
# 104  https://www.homedepot.com/p/CARRO-Wilkes-52-in...  2024-07-09
#
# [105 rows x 8 columns]

# %%
# Connect to the database
conn = sqlalchemy.create_engine(
'mysql+mysqlconnector://root:0803@localhost:3306/hd_products')

# %%
df.to_sql(name='products', con=conn, if_exists='replace', index=False)
# Out:
# 105
